# %%
import pandas as pd
import seaborn as sns 
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('data\stud.csv')

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.isna().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
uni = df['gender'].unique()
print(uni)

uni2 = df['race_ethnicity'].unique()
print(uni2)

uni3 = df['parental_level_of_education'].unique()
print(uni3)

uni1 = df['test_preparation_course'].unique()
print(uni1)
# Out:
# ['female' 'male']
# ['group B' 'group C' 'group A' 'group D' 'group E']
# ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# ['none' 'completed']

# %%
numberical_features = [ i for i in df.columns if df[i].dtype != 'object' ]
object__features = [ i for i in df.columns if df[i].dtype == 'object' ]

# %%
print(numberical_features)
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
print(object__features)
# Out:
# ['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch', 'test_preparation_course']

# %%
df.head(5)
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['total_score'] = df['math_score'] + df['reading_score']+ df['writing_score']
df['avg'] = df['total_score']/3
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score        avg
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
df.describe().T
# Out:
#                 count        mean        std   min         25%         50%  \
# math_score     1000.0   66.089000  15.163080   0.0   57.000000   66.000000
# reading_score  1000.0   69.169000  14.600192  17.0   59.000000   70.000000
# writing_score  1000.0   68.054000  15.195657  10.0   57.750000   69.000000
# total_score    1000.0  203.312000  42.771978  27.0  175.000000  205.000000
# avg            1000.0   67.770667  14.257326   9.0   58.333333   68.333333
#
#                       75%    max
# math_score      77.000000  100.0
# reading_score   79.000000  100.0
# writing_score   79.000000  100.0
# total_score    233.000000  300.0
# avg             77.666667  100.0

# %%
max_math_score = df['math_score'].max()
print(max_math_score)
# Out:
# 100

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))


sns.histplot(data=df, x='avg',hue='gender',ax=axs[0])
axs[0]

sns.histplot(data=df, x='avg',ax=axs[1])
# Out:
# <Axes: xlabel='avg', ylabel='Count'>

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='avg',kde=True,hue='lunch')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'],x='avg',kde=True,hue='lunch')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'],x='avg',kde=True,hue='lunch')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create the subplots (1 row, 3 columns)
fig, axs = plt.subplots(1, 3, figsize=(25, 6))

# Plot 1: Overall distribution with 'avg' and 'lunch' category
sns.histplot(data=df, x='avg', kde=True, hue='lunch', ax=axs[0])
axs[0].set_title('Overall Distribution of avg by Lunch')

# Plot 2: Distribution for females
sns.histplot(data=df[df.gender == 'female'], x='avg', kde=True, hue='lunch', ax=axs[1])
axs[1].set_title('Distribution of avg for Females by Lunch')

# Plot 3: Distribution for males
sns.histplot(data=df[df.gender == 'male'], x='avg', kde=True, hue='lunch', ax=axs[2])
axs[2].set_title('Distribution of avg for Males by Lunch')

# Display the plots
plt.tight_layout()
plt.show()

# %%
plt.subplots(1,3,figsize=(26,6))
plt.subplot(141)
ax =sns.histplot(data=df,x='avg',kde=True,hue='parental_level_of_education')
plt.subplot(142)
ax =sns.histplot(data=df[df.gender=='male'],x='avg',kde=True,hue='parental_level_of_education')
plt.subplot(143)
ax =sns.histplot(data=df[df.gender=='female'],x='avg',kde=True,hue='parental_level_of_education')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a 1x3 grid of subplots
plt.subplots(1, 3, figsize=(26, 6))

# Plot the first histogram with all data
plt.subplot(1, 3, 1)
ax = sns.histplot(data=df, x='avg', kde=True, hue='parental_level_of_education')

# Plot the second histogram with male data
plt.subplot(1, 3, 2)
ax = sns.histplot(data=df[df.gender == 'male'], x='avg', kde=True, hue='parental_level_of_education')

# Plot the third histogram with female data
plt.subplot(1, 3, 3)
ax = sns.histplot(data=df[df.gender == 'female'], x='avg', kde=True, hue='parental_level_of_education')

# Show the plots
plt.show()

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
ax =sns.histplot(data=df,x='avg',kde=True,hue='race_ethnicity')
plt.subplot(142)
ax =sns.histplot(data=df[df.gender=='female'],x='avg',kde=True,hue='race_ethnicity')
plt.subplot(143)
ax =sns.histplot(data=df[df.gender=='male'],x='avg',kde=True,hue='race_ethnicity')
plt.show()

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score        avg
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
plt.rcParams['figure.figsize'] = (30, 12)

plt.subplot(1, 5, 1)
size = df['gender'].value_counts()
labels = 'Female', 'Male'
color = ['red','green']


plt.pie(size, colors = color, labels = labels)
plt.title('Gender', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 2)
size = df['race_ethnicity'].value_counts()
labels = 'Group C', 'Group D','Group B','Group E','Group A'
color = ['red', 'green', 'blue', 'cyan','orange']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Race_Ethnicity', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 3)
size = df['lunch'].value_counts()
labels = 'Standard', 'Free'
color = ['red','green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Lunch', fontsize = 20)
plt.axis('off')


plt.subplot(1, 5, 4)
size = df['test_preparation_course'].value_counts()
labels = 'None', 'Completed'
color = ['red','green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Test Course', fontsize = 20)
plt.axis('off')


plt.subplot(1, 5, 5)
size = df['parental_level_of_education'].value_counts()
labels = 'Some College', "Associate's Degree",'High School','Some High School',"Bachelor's Degree","Master's Degree"
color = ['red', 'green', 'blue', 'cyan','orange','grey']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Parental Education', fontsize = 20)
plt.axis('off')


plt.tight_layout()
plt.grid()

plt.show()

# %%
gender_count = df['gender'].value_counts()
print(gender_count)
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
race = df['race_ethnicity'].value_counts()
print(race)
# Out:
# race_ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
lun = df['lunch'].value_counts()
print(lun)
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
sns.countplot(x=df['gender'],data=df,palette ='bright',ax=ax[0],saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
    
plt.pie(x=df['gender'].value_counts(),labels=['Male','Female'],explode=[0,0.1],autopct='%1.1f%%',shadow=True,colors=['#ff4d4d','#ff8000'])
plt.show()

# %%
ax=sns.countplot(x=df['gender'],data=df)
plt.show()

# %%
gender_group = df.groupby('gender').mean(numeric_only=True)
print(gender_group)
# Out:
#         math_score  reading_score  writing_score  total_score        avg
# gender
# female   63.633205      72.608108      72.467181   208.708494  69.569498
# male     68.728216      65.473029      63.311203   197.512448  65.837483

# %%
race = df['race_ethnicity'].value_counts()
print(race)
# Out:
# race_ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
gb = df.groupby('race_ethnicity').mean(numeric_only=True)
print (gb)
# Out:
#                 math_score  reading_score  writing_score  total_score  \
# race_ethnicity
# group A          61.629213      64.674157      62.674157   188.977528
# group B          63.452632      67.352632      65.600000   196.405263
# group C          64.463950      69.103448      67.827586   201.394984
# group D          67.362595      70.030534      70.145038   207.538168
# group E          73.821429      73.028571      71.407143   218.257143
#
#                       avg
# race_ethnicity
# group A         62.992509
# group B         65.468421
# group C         67.131661
# group D         69.179389
# group E         72.752381

# %%
prb = df.groupby('parental_level_of_education').mean(numeric_only=True)
print(prb)
# Out:
#                              math_score  reading_score  writing_score  \
# parental_level_of_education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268
#
#                              total_score        avg
# parental_level_of_education
# associate's degree            208.707207  69.569069
# bachelor's degree             215.771186  71.923729
# high school                   189.290816  63.096939
# master's degree               220.796610  73.598870
# some college                  205.429204  68.476401
# some high school              195.324022  65.108007

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score        avg
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
lunchgrp = df.groupby('lunch').mean(numeric_only=True)
print(lunchgrp)
# Out:
#               math_score  reading_score  writing_score  total_score        avg
# lunch
# free/reduced   58.921127      64.653521      63.022535   186.597183  62.199061
# standard       70.034109      71.654264      70.823256   212.511628  70.837209

# %%
Testpgrb = df.groupby('test_preparation_course').mean(numeric_only=True)
print(Testpgrb)
# Out:
#                          math_score  reading_score  writing_score  \
# test_preparation_course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673
#
#                          total_score        avg
# test_preparation_course
# completed                 218.008380  72.669460
# none                      195.116822  65.038941

# %%
sns.pairplot(df,hue = 'gender')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 7))



plt.subplot(2,2,1)
sns.boxplot(data=df, x='math_score',)

plt.subplot(2,2,2)
sns.boxplot(data=df, x='reading_score')


plt.subplot(2,2,3)
sns.boxplot(data=df, x='writing_score')


plt.subplot(2,2,4)
sns.boxplot(data=df, x='avg')
# Out:
# <Axes: xlabel='avg'>
